# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/weighted-opt/mnist
# Out:
# /content/gdrive/My Drive/weighted-opt/mnist

# %%
import putils
from putils import *
# %matplotlib inline

# %%
run-nmodel_sgd_lr0.01_Accuracy_train-tag-Accuracy.json

# %%
hs, epochs = 500, 20
record, plot_path = get_path_record(hs, epochs)

# %%
models =  ['sgmodel'] 
opts   = ['sgd'] # choose from: ['sgd', 'adagrad', 'adam']
lrs    = [0.01]# choose from: [0.1, 0.01, 0.001, 0.0001]
plot_H(record, models, opts, lrs)

# %%
metric = 'test_acc' # choose from: test_acc or train_loss
# choose from: ['nmodel', 'gmodel', 'jgmodel', 'wmodel', 'bmodel']
models =  [ 'nmodel', 'wmodel', 'gmodel', 'jgmodel', 'bmodel'] 
opts   = ['adagrad'] # choose from: ['sgd', 'adagrad', 'adam']
lrs    = [0.01]# choose from: [0.1, 0.01, 0.001, 0.0001]
gap = 3
plt.figure(1, (16, 4))
plt.ylim(97,100)
plot(record, metric, gap, models, opts, lrs, plot_path+"wgjgm_model_sgd_acc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-d8b3bd45b50c> in <module>()
#       7 plt.figure(1, (16, 4))
#       8 plt.ylim(97,100)
# ----> 9 plot(record, metric, gap, models, opts, lrs, plot_path+"wgjgm_model_sgd_acc")
#
# /content/gdrive/My Drive/weighted-opt/mnist/putils.py in plot(record, metric, gap, models, opts, lrs, file_name)
#      37             for lr in lrs:
#      38                 model_name = "{}_{}_lr{}".format(model, opt, lr)
# ---> 39                 plt.plot(record[model_name][metric][::gap], color=color[model], marker=marker[opt],
#      40                          linestyle=ls[str(lr)], label=model_name)
#      41     plt.legend()
#
# KeyError: 'nmodel_adagrad_lr0.01'

# %%
import numpy as np
lrs = ['0.1', '0.01', '0.001', '0.0001']
for i, lr in enumerate(lrs):
    plt.plot(np.array(record['gmodel_adagrad_lr{}'.format(lr)]['H'])+0.4*i , label = 'lr='+lr)
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.set()

# %%
import numpy as np
y = np.array(record['nmodel_adam_lr0.001']['train_loss'])
yr = np.std(rolling_window(y, 4), 1)
x = range(0, len(y))
xr = range(0, len(yr))
import pandas as pd
yy = pd.Series(y).rolling(4).std()
xx = range(0,len(yy))
ax = sns.lineplot(x=xr, y=yr, marker="s")
ax = sns.lineplot(x=x, y=y, marker='s' )
ax = sns.lineplot(x=xx, y=yy, marker='s' )
